# %% [markdown]
# # Winter School 2024 - EDA Tutorial
#
# This notebook highlights an exploratory data analysis using the example of the Titanic data set.
#
# Authors: Christopher Katins, Mario Sänger, Christopher Lazik, Thomas Kosch
# Credits to Patrick Schäfer (HU Berlin)
#
# ------------
#
# Contents of the Notebook:
#
# ### Part 1: Exploratory Data Analysis(EDA):
#
# 1. Analysis of features.
# 2. Finding relations or trends between features.
#
# ### Part 2: Feature Engineering and Data Cleaning:
#
# 1. Adding features.
# 2. Removing features.
# 3. Converting features into suitable form for modeling.
#
# ### Part 3: Predictive Modeling
#
# 1. Running a simple Algorithm.
#
#
# # Part 1: Exploratory Data Analysis(EDA)

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %%
#URL = "https://box.hu-berlin.de/f/74677a3101b742cfab2c/?dl=1"
data = pd.read_csv(URL)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# !pip install matplotlib==3.7.3
# !pip install statsmodels
# Out:
# Requirement already satisfied: matplotlib==3.7.3 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (3.7.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from matplotlib==3.7.3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from matplotlib==3.7.3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from matplotlib==3.7.3) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from matplotlib==3.7.3) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from matplotlib==3.7.3) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from matplotlib==3.7.3) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from matplotlib==3.7.3) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from matplotlib==3.7.3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from matplotlib==3.7.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.7.3) (1.16.0)
# Requirement already satisfied: statsmodels in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (0.14.1)
# Requirement already satisfied: numpy<2,>=1.18 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from statsmodels) (1.26.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from statsmodels) (1.11.4)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from statsmodels) (2.1.4)
# Requirement already satisfied: patsy>=0.5.4 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from statsmodels) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: six in /home/mario/anaconda3/envs/winterschool/lib/python3.10/site-packages (from patsy>=0.5.4->statsmodels) (1.16.0)

# %% [markdown]
# # Basic Structure
#
# Use .info() to get brief information about the dataframe

# %% [markdown]
# ## Types of Features
#
# - Nominal Features:
#     - Sex, Embarked, Name, Ticket
#
# - Ordinal Features:
#     - PClass
#
# - Continous Feature:
#     - Age, Fare
#
# - Discrete Features:
#     - SibSp, Parch

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# # Null Values and Summary Statistics

# %%
# Categorical
data.describe(include="O")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# Numerical
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Missing Values

# %%
#checking for total null values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# The `Age`, `Cabin` and `Embarked` have null values. we will try to infer them from the data.

# %%
# checking for duplicates
data.duplicated().any()
# Out:
# False

# %% [markdown]
# No duplicated rows

# %% [markdown]
# # Survival rates

# %%
f,ax=plt.subplots(1,2,figsize=(12,6))
data['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.1f%%', ax=ax[0])
ax[0].set_title('Relative Survival Rates')
ax[0].set_ylabel('')

sns.countplot(x='Survived', data=data, ax=ax[1])
sns.despine()
ax[1].set_title('Absolute Survival Rate');

# %% [markdown]
# **Observation:**
# - Out of 891 passengers in training set, only around 350 survived
# - That is: 38.4% survived
#
# We will  dig down deeper to get better insights and see which features of the passengers increased the chance of survival

# %% [markdown]
# # Key Question: What influenced the chance of survival?

# %% [markdown]
# ## Factor Sex
#
# We will first build a crosstab between Sex and Survival Rates.

# %%
pd.crosstab(data.Sex,data.Survived,margins=True)  \
    .style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_cd309_row0_col0, #T_cd309_row0_col2, #T_cd309_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cd309_row0_col1 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_cd309_row1_col0 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_cd309_row1_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_cd309_row2_col0, #T_cd309_row2_col1, #T_cd309_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cd309">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_cd309_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cd309_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_cd309_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd309_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_cd309_row0_col0" class="data row0 col0" >81</td>
#       <td id="T_cd309_row0_col1" class="data row0 col1" >233</td>
#       <td id="T_cd309_row0_col2" class="data row0 col2" >314</td>
#     </tr>
#     <tr>
#       <th id="T_cd309_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_cd309_row1_col0" class="data row1 col0" >468</td>
#       <td id="T_cd309_row1_col1" class="data row1 col1" >109</td>
#       <td id="T_cd309_row1_col2" class="data row1 col2" >577</td>
#     </tr>
#     <tr>
#       <th id="T_cd309_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_cd309_row2_col0" class="data row2 col0" >549</td>
#       <td id="T_cd309_row2_col1" class="data row2 col1" >342</td>
#       <td id="T_cd309_row2_col2" class="data row2 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We will next use a histogram to show the relation

# %%
f,ax=plt.subplots(1,1,figsize=(6,4))
# sns.countplot(x='Sex',hue='Survived',data=data,ax=ax)
sns.pointplot(x='Sex', y='Survived', ax=ax, data=data)
ax.set_title('Factor of Sex - Survived vs Dead')
sns.despine()
plt.show()

# %% [markdown]
# **Observation:** We can clearly see that female passengers had a much higher rate of survival.

# %% [markdown]
# ## Factor PClass

# %%
ct = pd.crosstab(data.Pclass,data.Survived,margins=True) \
    .style.background_gradient(cmap='Blues')
display(ct)

ct = pd.crosstab(data.Pclass,data.Survived,margins=True, normalize=True) \
    .style.background_gradient(cmap='Blues')
display(ct)


f,ax=plt.subplots(1,1,figsize=(6,4))
# sns.countplot(x='Pclass',hue='Survived',data=data,ax=ax)
sns.pointplot(x='Pclass', y='Survived', ax=ax, data=data)
ax.set_title('Pclass:Survived vs Dead')
sns.despine()
plt.show()
# Out:
# <style type="text/css">
# #T_a7e42_row0_col0, #T_a7e42_row1_col1, #T_a7e42_row1_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a7e42_row0_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_a7e42_row0_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_a7e42_row1_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_a7e42_row2_col0 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_a7e42_row2_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_a7e42_row2_col2 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_a7e42_row3_col0, #T_a7e42_row3_col1, #T_a7e42_row3_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a7e42">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_a7e42_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a7e42_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a7e42_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7e42_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a7e42_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_a7e42_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_a7e42_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_a7e42_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a7e42_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_a7e42_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_a7e42_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_a7e42_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a7e42_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_a7e42_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_a7e42_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_a7e42_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_a7e42_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_a7e42_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_a7e42_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_497e5_row0_col0, #T_497e5_row1_col1, #T_497e5_row1_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_497e5_row0_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_497e5_row0_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_497e5_row1_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_497e5_row2_col0 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_497e5_row2_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_497e5_row2_col2 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_497e5_row3_col0, #T_497e5_row3_col1, #T_497e5_row3_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_497e5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_497e5_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_497e5_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_497e5_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_497e5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_497e5_row0_col0" class="data row0 col0" >0.089787</td>
#       <td id="T_497e5_row0_col1" class="data row0 col1" >0.152637</td>
#       <td id="T_497e5_row0_col2" class="data row0 col2" >0.242424</td>
#     </tr>
#     <tr>
#       <th id="T_497e5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_497e5_row1_col0" class="data row1 col0" >0.108866</td>
#       <td id="T_497e5_row1_col1" class="data row1 col1" >0.097643</td>
#       <td id="T_497e5_row1_col2" class="data row1 col2" >0.206510</td>
#     </tr>
#     <tr>
#       <th id="T_497e5_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_497e5_row2_col0" class="data row2 col0" >0.417508</td>
#       <td id="T_497e5_row2_col1" class="data row2 col1" >0.133558</td>
#       <td id="T_497e5_row2_col2" class="data row2 col2" >0.551066</td>
#     </tr>
#     <tr>
#       <th id="T_497e5_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_497e5_row3_col0" class="data row3 col0" >0.616162</td>
#       <td id="T_497e5_row3_col1" class="data row3 col1" >0.383838</td>
#       <td id="T_497e5_row3_col2" class="data row3 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observation:** We can clearly see that passengers of class 1 were given a high priority while rescue.

# %% [markdown]
# ## Sex AND Pclass

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True) \
    .style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_a3d3b_row0_col0, #T_a3d3b_row0_col1, #T_a3d3b_row0_col3, #T_a3d3b_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a3d3b_row0_col2, #T_a3d3b_row1_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_a3d3b_row1_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_a3d3b_row1_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_a3d3b_row1_col3 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_a3d3b_row2_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_a3d3b_row2_col1, #T_a3d3b_row2_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_a3d3b_row2_col2 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_a3d3b_row3_col0 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_a3d3b_row3_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_a3d3b_row3_col3 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_a3d3b_row4_col0, #T_a3d3b_row4_col1, #T_a3d3b_row4_col2, #T_a3d3b_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a3d3b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_a3d3b_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_a3d3b_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_a3d3b_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_a3d3b_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3d3b_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_a3d3b_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_a3d3b_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_a3d3b_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_a3d3b_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_a3d3b_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_a3d3b_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_a3d3b_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_a3d3b_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_a3d3b_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_a3d3b_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_a3d3b_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_a3d3b_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_a3d3b_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_a3d3b_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_a3d3b_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_a3d3b_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_a3d3b_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_a3d3b_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_a3d3b_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_a3d3b_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_a3d3b_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_a3d3b_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_a3d3b_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_a3d3b_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_a3d3b_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_a3d3b_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_a3d3b_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.catplot(x='Pclass', y='Survived', hue='Sex', kind='point', data=data)
sns.despine()
plt.show()

# %% [markdown]
# **Observation:** The chances of survival were highest, if you were female and in the first passenger class.

# %% [markdown]
# ## Age

# %%
print('Oldest Passenger was:',data['Age'].max(),'Years')
print('Youngest Passenger was:',data['Age'].min(),'Years')
# Out:
# Oldest Passenger was: 80.0 Years
# Youngest Passenger was: 0.42 Years

# %%
sns.displot(x="Age", hue="Survived", col="Sex", 
            data=data, element="poly", height = 3
            );

# %% [markdown]
# **Observations:**
#
# 1. Survival rates for passenegers below age 10 is increased
# 2. Survival chances for passenegers aged 20-50 from Pclass 1 is highest, and even better for women.
# 3. The Women and Child first policy thus holds true

# %% [markdown]
# # Filling Missing Values

# %% [markdown]
# ## Filling AGE
#
# As we had seen earlier, the Age feature has 177 null values.
# The Name feature has a salutation like Mr or Mrs. Thus we may use it to guess the age of   respective groups.

# %%
data[["Name"]].head()
# Out:
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %% [markdown]
# We are using a Regex. It returns strings that contain A-Z or a-z and are followed by a puncation .(dot)

# %%
data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')
data[["Initial"]].head()
# Out:
#   Initial
# 0      Mr
# 1     Mrs
# 2    Miss
# 3     Mrs
# 4      Mr

# %% [markdown]
# ### Checking Frequency of Initial

# %%
pd.crosstab(data.Initial,data.Sex).T \
    .style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_91a28_row0_col0, #T_91a28_row0_col1, #T_91a28_row0_col3, #T_91a28_row0_col4, #T_91a28_row0_col5, #T_91a28_row0_col7, #T_91a28_row0_col8, #T_91a28_row0_col12, #T_91a28_row0_col15, #T_91a28_row0_col16, #T_91a28_row1_col2, #T_91a28_row1_col6, #T_91a28_row1_col9, #T_91a28_row1_col10, #T_91a28_row1_col11, #T_91a28_row1_col13, #T_91a28_row1_col14 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_91a28_row0_col2, #T_91a28_row0_col6, #T_91a28_row0_col9, #T_91a28_row0_col10, #T_91a28_row0_col11, #T_91a28_row0_col13, #T_91a28_row0_col14, #T_91a28_row1_col0, #T_91a28_row1_col1, #T_91a28_row1_col3, #T_91a28_row1_col4, #T_91a28_row1_col5, #T_91a28_row1_col7, #T_91a28_row1_col8, #T_91a28_row1_col12, #T_91a28_row1_col15, #T_91a28_row1_col16 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_91a28">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_91a28_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_91a28_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_91a28_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_91a28_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_91a28_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_91a28_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_91a28_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_91a28_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_91a28_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_91a28_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_91a28_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_91a28_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_91a28_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_91a28_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_91a28_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_91a28_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_91a28_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91a28_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_91a28_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_91a28_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_91a28_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_91a28_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_91a28_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_91a28_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_91a28_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_91a28_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_91a28_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_91a28_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_91a28_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_91a28_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_91a28_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_91a28_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_91a28_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_91a28_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_91a28_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_91a28_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_91a28_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_91a28_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_91a28_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_91a28_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_91a28_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_91a28_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_91a28_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_91a28_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_91a28_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_91a28_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_91a28_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_91a28_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_91a28_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_91a28_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_91a28_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_91a28_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_91a28_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.groupby('Initial')[['Age']].mean()
# Out:
#                 Age
# Initial
# Capt      70.000000
# Col       58.000000
# Countess  33.000000
# Don       40.000000
# Dr        42.000000
# Jonkheer  38.000000
# Lady      48.000000
# Major     48.500000
# Master     4.574167
# Miss      21.773973
# Mlle      24.000000
# Mme       24.000000
# Mr        32.368090
# Mrs       35.898148
# Ms        28.000000
# Rev       43.166667
# Sir       49.000000

# %% [markdown]
# **Observations:** There are some misspelled initials like Mlle or Mme that stand for Miss

# %%
data['Initial'].replace(
    ['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
    ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'], inplace=True)

# %%
data.groupby('Initial')[['Age']].mean()
# Out:
#                Age
# Initial
# Master    4.574167
# Miss     21.860000
# Mr       32.739609
# Mrs      35.981818
# Other    45.888889

# %% [markdown]
# **Observations:** Master can be matched to male children. Miss is less distinct.

# %% [markdown]
# ## Filling Missing Ages by Intial-Averages

# %%
data[data["Age"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked Initial
# 5      male  NaN      0      0      330877   8.4583   NaN        Q      Mr
# 17     male  NaN      0      0      244373  13.0000   NaN        S      Mr
# 19   female  NaN      0      0        2649   7.2250   NaN        C     Mrs
# 26     male  NaN      0      0        2631   7.2250   NaN        C      Mr
# 28   female  NaN      0      0      330959   7.8792   NaN        Q    Miss
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C      Mr
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S    Miss
# 868    male  NaN      0      0      345777   9.5000   NaN        S      Mr
# 878    male  NaN      0      0      349217   7.8958   NaN        S      Mr
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S    Miss
#
# [177 rows x 13 columns]

# %%
data.Age.fillna(data.groupby("Initial").Age.transform(np.mean), inplace=True)
# Out:
# /tmp/ipykernel_123764/838785203.py:1: FutureWarning: The provided callable <function mean at 0x7f4fd426f130> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.Age.fillna(data.groupby("Initial").Age.transform(np.mean), inplace=True)

# %%
data.Age.isnull().any()
# Out:
# False

# %%
sns.catplot(x='Pclass', y='Survived', col='Initial', kind="point", data=data, height=2)
sns.despine()
plt.show()

# %% [markdown]
# **Observation:** The Women and Child first policy thus holds true

# %% [markdown]
# # Embarked

# %%
sns.catplot(x='Embarked', y='Survived', kind="point", data=data, height=3);

# %% [markdown]
# **Observation:** The chances for survival for Port C is highest around 0.55 while it is lowest for S.

# %%
sns.catplot(x='Pclass',y='Survived', kind="point", hue='Sex',col='Embarked',data=data, height=3);

# %% [markdown]
# **Observations:**
#
# - The survival rates are ~1 for women from Pclass 1 and Pclass 2 irrespective of the port
# - Port S is worst for Pclass 3
# - Port Q is worst for Men

# %% [markdown]
# # Filling Emarked NaN
#
# There are two missing values for `Embarked`

# %%
data[data.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked Initial
# 61   female  38.0      0      0  113572  80.0   B28      NaN    Miss
# 829  female  62.0      0      0  113572  80.0   B28      NaN     Mrs

# %% [markdown]
# As we saw that most passengers boarded from Port S, we replace NaN with S.

# %%
print(data.Embarked.mode())
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
data.Embarked.fillna("S", inplace=True)
data.Embarked.isnull().any()
# Out:
# False

# %%
data[data.Embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Initial]
# Index: []

# %% [markdown]
# # SibSip
#
# This feature represents whether a person is alone or with his family members.
#
# Sibling = brother, sister, stepbrother, stepsister
#
# Spouse = husband, wife

# %%
pd.crosstab(data.SibSp, data.Survived, normalize=True) \
    .style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_80eca_row0_col0, #T_80eca_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_80eca_row1_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_80eca_row1_col1 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_80eca_row2_col0, #T_80eca_row4_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_80eca_row2_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_80eca_row3_col0, #T_80eca_row3_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_80eca_row4_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_80eca_row5_col0, #T_80eca_row5_col1, #T_80eca_row6_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_80eca_row6_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_80eca">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_80eca_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_80eca_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80eca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80eca_row0_col0" class="data row0 col0" >0.446689</td>
#       <td id="T_80eca_row0_col1" class="data row0 col1" >0.235690</td>
#     </tr>
#     <tr>
#       <th id="T_80eca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80eca_row1_col0" class="data row1 col0" >0.108866</td>
#       <td id="T_80eca_row1_col1" class="data row1 col1" >0.125701</td>
#     </tr>
#     <tr>
#       <th id="T_80eca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80eca_row2_col0" class="data row2 col0" >0.016835</td>
#       <td id="T_80eca_row2_col1" class="data row2 col1" >0.014590</td>
#     </tr>
#     <tr>
#       <th id="T_80eca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80eca_row3_col0" class="data row3 col0" >0.013468</td>
#       <td id="T_80eca_row3_col1" class="data row3 col1" >0.004489</td>
#     </tr>
#     <tr>
#       <th id="T_80eca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80eca_row4_col0" class="data row4 col0" >0.016835</td>
#       <td id="T_80eca_row4_col1" class="data row4 col1" >0.003367</td>
#     </tr>
#     <tr>
#       <th id="T_80eca_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_80eca_row5_col0" class="data row5 col0" >0.005612</td>
#       <td id="T_80eca_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80eca_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_80eca_row6_col0" class="data row6 col0" >0.007856</td>
#       <td id="T_80eca_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(data.SibSp,data.Pclass, normalize=True) \
    .style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_2f52c_row0_col0, #T_2f52c_row0_col1, #T_2f52c_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2f52c_row1_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_2f52c_row1_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_2f52c_row1_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_2f52c_row2_col0, #T_2f52c_row4_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_2f52c_row2_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_2f52c_row2_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_2f52c_row3_col0, #T_2f52c_row3_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_2f52c_row3_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_2f52c_row4_col0, #T_2f52c_row4_col1, #T_2f52c_row5_col0, #T_2f52c_row5_col1, #T_2f52c_row5_col2, #T_2f52c_row6_col0, #T_2f52c_row6_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2f52c_row6_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_2f52c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_2f52c_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_2f52c_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_2f52c_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f52c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f52c_row0_col0" class="data row0 col0" >0.153760</td>
#       <td id="T_2f52c_row0_col1" class="data row0 col1" >0.134680</td>
#       <td id="T_2f52c_row0_col2" class="data row0 col2" >0.393939</td>
#     </tr>
#     <tr>
#       <th id="T_2f52c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2f52c_row1_col0" class="data row1 col0" >0.079686</td>
#       <td id="T_2f52c_row1_col1" class="data row1 col1" >0.061728</td>
#       <td id="T_2f52c_row1_col2" class="data row1 col2" >0.093154</td>
#     </tr>
#     <tr>
#       <th id="T_2f52c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2f52c_row2_col0" class="data row2 col0" >0.005612</td>
#       <td id="T_2f52c_row2_col1" class="data row2 col1" >0.008979</td>
#       <td id="T_2f52c_row2_col2" class="data row2 col2" >0.016835</td>
#     </tr>
#     <tr>
#       <th id="T_2f52c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2f52c_row3_col0" class="data row3 col0" >0.003367</td>
#       <td id="T_2f52c_row3_col1" class="data row3 col1" >0.001122</td>
#       <td id="T_2f52c_row3_col2" class="data row3 col2" >0.013468</td>
#     </tr>
#     <tr>
#       <th id="T_2f52c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2f52c_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_2f52c_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_2f52c_row4_col2" class="data row4 col2" >0.020202</td>
#     </tr>
#     <tr>
#       <th id="T_2f52c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2f52c_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_2f52c_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_2f52c_row5_col2" class="data row5 col2" >0.005612</td>
#     </tr>
#     <tr>
#       <th id="T_2f52c_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_2f52c_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_2f52c_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_2f52c_row6_col2" class="data row6 col2" >0.007856</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(figsize=(8,4))
sns.pointplot(x='SibSp', y='Survived', hue="Pclass", data=data, ax=ax)
ax.set_title('SibSp vs Survived')
# Out:
# Text(0.5, 1.0, 'SibSp vs Survived')

# %% [markdown]
# **Observation:**
# - Plcass 1 and 2 had highest chances of survival
# - Families with 3 Members had highest chances of survival
# - Families >3 were only in Pclass 3
# - Survival for families with >5 members is 0%.

# %% [markdown]
# # Fare

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Average Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.204207968574636

# %%
f,ax=plt.subplots(1,3,figsize=(12,4))
sns.histplot(x=data[data['Pclass']==1].Fare,kde=True,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')

sns.histplot(x=data[data['Pclass']==2].Fare,kde=True,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')

sns.histplot(x=data[data['Pclass']==3].Fare,kde=True,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')

plt.show()
sns.boxplot(x="Pclass", y="Fare", hue="Sex", data=data);

# %% [markdown]
# **Observation:** There seems to be a large spread in distributions of fares. Some outliers.

# %% [markdown]
# # Log transformed Data

# %%
def get_fare(data, pclass):
    fare = data[data['Pclass']==pclass].Fare
    return np.log2(fare[fare>0])

np.seterr(divide = 'ignore')
f,ax=plt.subplots(1,3,figsize=(12,4))
sns.histplot(x=get_fare(data,1),kde=True,ax=ax[0])
sns.despine()
ax[0].set_title('Fares in Pclass 1')
sns.histplot(x=get_fare(data,2),kde=True,ax=ax[1])
sns.despine()
ax[1].set_title('Fares in Pclass 2')
sns.histplot(x=get_fare(data,3),kde=True,ax=ax[2])
sns.despine()
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# ## QQ-Plot - Test for Normality

# %%
import statsmodels.api as sm
ax = sm.qqplot(get_fare(data,1), fit=True, line="45");
ax.suptitle("Plcass 1")
sm.qqplot(get_fare(data,2), fit=True, line="45");
sm.qqplot(get_fare(data,3), fit=True, line="45");

# %% [markdown]
# **Observation**: No signs of normal distribution, even for log-transformed data

# %% [markdown]
# # Part 2: Feature Engineering and Data Cleaning

# %% [markdown]
# # Family_Size and Alone

# %%
data['Family_Size'] = 0
data['Family_Size'] = data['Parch']+data['SibSp']
data['Alone'] = data.Family_Size==0

ax = sns.pointplot(x='Alone',y='Survived', hue="Pclass", data=data)
ax.set_title("Traveling Alone");

# %% [markdown]
# **Observation** If you were alone then chances for survival is very low.

# %%
ax = sns.pointplot(x='Alone',y='Survived',data=data, hue='Sex')

# %% [markdown]
# Observation: chances of females, who are alone, are higher than those with family.

# %% [markdown]
# # Outlier Handling - Binning Fares

# %%
data['Fare_Range'] = pd.qcut(data['Fare'],4,labels=["Small","Medium","Large", "Rich"])
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='Blues')
# Out:
# /tmp/ipykernel_123764/1835988229.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='Blues')
# <style type="text/css">
# #T_ed62a_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ed62a_row1_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_ed62a_row2_col0 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_ed62a_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ed62a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed62a_level0_col0" class="col_heading level0 col0" >Survived</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fare_Range</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed62a_level0_row0" class="row_heading level0 row0" >Small</th>
#       <td id="T_ed62a_row0_col0" class="data row0 col0" >0.197309</td>
#     </tr>
#     <tr>
#       <th id="T_ed62a_level0_row1" class="row_heading level0 row1" >Medium</th>
#       <td id="T_ed62a_row1_col0" class="data row1 col0" >0.303571</td>
#     </tr>
#     <tr>
#       <th id="T_ed62a_level0_row2" class="row_heading level0 row2" >Large</th>
#       <td id="T_ed62a_row2_col0" class="data row2 col0" >0.454955</td>
#     </tr>
#     <tr>
#       <th id="T_ed62a_level0_row3" class="row_heading level0 row3" >Rich</th>
#       <td id="T_ed62a_row3_col0" class="data row3 col0" >0.581081</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observation:** We observe that as the fare increases, the chances of survival increases.

# %% [markdown]
# # Encoding Categorical Values

# %%
data_numerical = pd.get_dummies(data, columns=['Sex'], prefix='is')
data_numerical = pd.get_dummies(data_numerical, columns=['Embarked'], prefix='is')
data_numerical = pd.get_dummies(data_numerical, columns=['Initial'], prefix='is')
data_numerical = pd.get_dummies(data_numerical, columns=['Fare_Range'], prefix='is')

# %% [markdown]
# # Correlation Between The Numerical Features

# %%
fig, ax = plt.subplots(figsize=(16,12))
sns.heatmap(data_numerical.corr(numeric_only=True), annot=True, linewidths=0.2, ax=ax)
plt.tight_layout()
plt.show()

# %% [markdown]
# There is high correlation between `survived` and `Pclass`, `Fare`, `is_female`, `is_male` `is_S`, `is_C`, `is_Mr`, `is_Mrs`, `is_Miss`, `alone`, `is_rich`

# %% [markdown]
# # Observations in a Nutshell for all features:
#
# - Sex:
#     - The chance of survival for women is high as compared to men
# - Pclass:
#     - Fares varied significantly with few passengers (<1%) paying as high as $512
#     - The more you pay, the better chances of survival
#     - The survival rate for Pclass3 is very low
# - Age:
#     - Children between 5-10 years do have a high chance of survival
# - Embarked:
#     - The chances of survival at C and S were high for lower passenger classes
# - Parch+SibSp:
#     - Having a small family  gives a greater chance of than traveling alone (as male) or having a large family travelling with you
#     - Females travel best alone

# %% [markdown]
# # Part 3: Predictive Modeling
#
# - We have gained insights from the EDA
# - Using this insights, we cannot accurately predict whether a passenger will survive or not
# - So we may use a classification algorithm to predict whether the Passenger will survive

# %%
from sklearn.linear_model import RidgeClassifierCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# display(data_numerical.head())
train_y = data_numerical['Survived']
train_X = data_numerical.drop(columns=['Survived', 'Name', 'Ticket', 'Cabin'])

# Scaled data has zero mean and unit variance:
# deprecated:
# train_X = StandardScaler().fit_transform(train_X)
# clf = RidgeClassifierCV(alphas=np.logspace(-3, 3, 10), normalize=True).fit(train_X, train_y)
# score = clf.score(train_X, train_y)
# print ("Accuracy of Model: ", score)

# Train Regression model
clf = make_pipeline(StandardScaler(), 
                    RidgeClassifierCV(alphas=np.logspace(-3, 3, 10))).fit(train_X, train_y)
score = clf.score(train_X, train_y)

print ("Accuracy of Model: ", score)
# Out:
# Accuracy of Model:  0.8327721661054994
